# %%
cd ..
# Out:
# /Users/cm772/Documents/Dev/tptp-features

# %%
SINGLE_TIMEOUT = 60*5
TOTAL_TIMEOUT = 3600*8

# %%
from tptp_features.strategic_features import get_features

# %%
data, incomplete = get_features("../tptp-parser/", SINGLE_TIMEOUT, TOTAL_TIMEOUT)
# Out:
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/GEO/GEO510+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/GEO/GEO510+1.p
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/GEO/GEO511+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/GEO/GEO511+1.p
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV106_1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV092-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV100-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV094+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV088=1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV090-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV125_1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV125-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/HWV/HWV126_1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/HWV/HWV126_1.p
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV124+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/SYN/SYN853-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/HWV/HWV094_1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/HWV/HWV094_1.p
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/HWV/HWV127+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/HWV/HWV127+1.p
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV106+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV134=1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV096-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV088_1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/SWW/SWW678=1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/SWW/SWW678=1.p
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/HWV/HWV125=1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/HWV/HWV125=1.p
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV127=1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/HWV/HWV123-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/HWV/HWV123-1.p
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV131-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/HWV/HWV127_1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/HWV/HWV127_1.p
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV128-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/SWW/SWW677=1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/SWW/SWW677=1.p
# ERROR:root:Timed-out: ../tptp-parser/Problems/LCL/LCL680+1.020.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV132-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV096_1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV096=1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/SYN/SYN854-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/GEO/GEO538+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/GEO/GEO538+1.p
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV126=1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV094-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV088-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV134_1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV126-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/GEO/GEO408^1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/GEO/GEO408^1.p
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV100+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV092+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/HWV/HWV124-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/HWV/HWV124-1.p
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/GEO/GEO539+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/GEO/GEO539+1.p
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/SWW/SWW676=1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/SWW/SWW676=1.p
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV133-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
# ...
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/SYN/SYN855-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/HWV/HWV133_1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/HWV/HWV133_1.p
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV134-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/HWV/HWV133=1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/HWV/HWV133=1.p
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV128+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/SYN/SYN852-1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV123_1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Future returned an exception: ../tptp-parser/Problems/HWV/HWV124_1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 136, in get_problem_features_rq
#     raise ProblemFeaturesFailedException(filename, timeout, e)
# tptp_features.strategic_features.ProblemFeaturesFailedException: ../tptp-parser/Problems/HWV/HWV124_1.p
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV096+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV125+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV132+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV088+1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV132_1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed
# ERROR:root:Timed-out: ../tptp-parser/Problems/HWV/HWV100=1.p
# Traceback (most recent call last):
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 160, in get_features
#     s = future.result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/cm772/Documents/Dev/tptp-features/tptp_features/strategic_features.py", line 143, in get_problem_features_rq
#     raise ProblemFeaturesTimeoutException(filename, timeout, "Waited for rq, but failed")
# tptp_features.strategic_features.ProblemFeaturesTimeoutException: Waited for rq, but failed

# %%
import pandas as pd

# %%
incomplete = pd.Series([(p.parent.name, p.name) for p in incomplete])

# %%
incomplete.describe()
# Out:
# count                    79
# unique                   79
# top       (GEO, GEO538+1.p)
# freq                      1
# dtype: object

# %%
store = pd.HDFStore('problem_features.h5')
store['features'] = data
store['incomplete'] = incomplete
store['timeouts'] = pd.Series(dict(single=SINGLE_TIMEOUT, total=TOTAL_TIMEOUT))
store.close()
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->values] [items->None]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
incomplete
# Out:
# 0     (GEO, GEO511+1.p)
# 1     (HWV, HWV088-1.p)
# 2     (HWV, HWV127+1.p)
# 3     (SYN, SYN852-1.p)
# 4     (HWV, HWV128_1.p)
#             ...
# 74    (HWV, HWV106=1.p)
# 75    (SYN, SYN853-1.p)
# 76    (HWV, HWV088=1.p)
# 77    (HWV, HWV128-1.p)
# 78    (SWW, SWW676=1.p)
# Length: 79, dtype: object
